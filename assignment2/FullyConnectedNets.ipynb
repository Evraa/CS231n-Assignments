# %% [markdown]
# # Fully-Connected Neural Nets
# In the previous homework you implemented a fully-connected two-layer neural network on CIFAR-10. The implementation was simple but not very modular since the loss and gradient were computed in a single monolithic function. This is manageable for a simple two-layer network, but would become impractical as we move to bigger models. Ideally we want to build networks using a more modular design so that we can implement different layer types in isolation and then snap them together into models with different architectures.

# %% [markdown]
# In this exercise we will implement fully-connected networks using a more modular approach. For each layer we will implement a `forward` and a `backward` function. The `forward` function will receive inputs, weights, and other parameters and will return both an output and a `cache` object storing data needed for the backward pass, like this:
#
# ```python
# def layer_forward(x, w):
#   """ Receive inputs x and weights w """
#   # Do some computations ...
#   z = # ... some intermediate value
#   # Do some more computations ...
#   out = # the output
#
#   cache = (x, w, z, out) # Values we need to compute gradients
#
#   return out, cache
# ```
#
# The backward pass will receive upstream derivatives and the `cache` object, and will return gradients with respect to the inputs and weights, like this:
#
# ```python
# def layer_backward(dout, cache):
#   """
#   Receive dout (derivative of loss with respect to outputs) and cache,
#   and compute derivative with respect to inputs.
#   """
#   # Unpack cache values
#   x, w, z, out = cache
#
#   # Use values in cache to compute derivatives
#   dx = # Derivative of loss with respect to x
#   dw = # Derivative of loss with respect to w
#
#   return dx, dw
# ```
#
# After implementing a bunch of layers this way, we will be able to easily combine them to build classifiers with different architectures.
#
# In addition to implementing fully-connected networks of arbitrary depth, we will also explore different update rules for optimization, and introduce Dropout as a regularizer and Batch/Layer Normalization as a tool to more efficiently optimize deep networks.

# %%
# As usual, a bit of setup
from __future__ import print_function
import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# =========== You can safely ignore the message below if you are NOT working on ConvolutionalNetworks.ipynb ===========
# 	You will need to compile a Cython extension for a portion of this assignment.
# 	The instructions to do this will be given in a section of the notebook below.
# 	There will be an option for Colab users and another for Jupyter (local) users.

# %%
# Load the (preprocessed) CIFAR10 data.

data = get_CIFAR10_data()
for k, v in list(data.items()):
  print(('%s: ' % k, v.shape))
# Out:
# ('X_train: ', (49000, 3, 32, 32))
# ('y_train: ', (49000,))
# ('X_val: ', (1000, 3, 32, 32))
# ('y_val: ', (1000,))
# ('X_test: ', (1000, 3, 32, 32))
# ('y_test: ', (1000,))

# %% [markdown]
# # Affine layer: forward
# Open the file `cs231n/layers.py` and implement the `affine_forward` function.
#
# Once you are done you can test your implementaion by running the following:

# %%
# Test the affine_forward function

num_inputs = 2
input_shape = (4, 5, 6)
output_dim = 3

input_size = num_inputs * np.prod(input_shape)
weight_size = output_dim * np.prod(input_shape)

x = np.linspace(-0.1, 0.5, num=input_size).reshape(num_inputs, *input_shape)
w = np.linspace(-0.2, 0.3, num=weight_size).reshape(np.prod(input_shape), output_dim)
b = np.linspace(-0.3, 0.1, num=output_dim)

out, _ = affine_forward(x, w, b)
correct_out = np.array([[ 1.49834967,  1.70660132,  1.91485297],
                        [ 3.25553199,  3.5141327,   3.77273342]])

# Compare your output with ours. The error should be around e-9 or less.
print('Testing affine_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing affine_forward function:
# difference:  9.769847728806635e-10

# %% [markdown]
# # Affine layer: backward
# Now implement the `affine_backward` function and test your implementation using numeric gradient checking.

# %%
# Test the affine_backward function
np.random.seed(231)
x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 5)
b = np.random.randn(5)
dout = np.random.randn(10, 5)

dx_num = eval_numerical_gradient_array(lambda x: affine_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_forward(x, w, b)[0], b, dout)

_, cache = affine_forward(x, w, b)
dx, dw, db = affine_backward(dout, cache)

# The error should be around e-10 or less
print('Testing affine_backward function:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_backward function:
# dx error:  5.399100368651805e-11
# dw error:  9.904211865398145e-11
# db error:  2.4122867568119087e-11

# %% [markdown]
# # ReLU activation: forward
# Implement the forward pass for the ReLU activation function in the `relu_forward` function and test your implementation using the following:

# %%
# Test the relu_forward function

x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out, _ = relu_forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

# Compare your output with ours. The error should be on the order of e-8
print('Testing relu_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing relu_forward function:
# difference:  4.999999798022158e-08

# %% [markdown]
# # ReLU activation: backward
# Now implement the backward pass for the ReLU activation function in the `relu_backward` function and test your implementation using numeric gradient checking:

# %%
np.random.seed(231)
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: relu_forward(x)[0], x, dout)

_, cache = relu_forward(x)
dx = relu_backward(dout, cache)

# The error should be on the order of e-12
print('Testing relu_backward function:')
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing relu_backward function:
# dx error:  3.2756349136310288e-12

# %% [markdown]
# ## Inline Question 1:
#
# We've only asked you to implement ReLU, but there are a number of different activation functions that one could use in neural networks, each with its pros and cons. In particular, an issue commonly seen with activation functions is getting zero (or close to zero) gradient flow during backpropagation. Which of the following activation functions have this problem? If you consider these functions in the one dimensional case, what types of input would lead to this behaviour?
# 1. Sigmoid
# 2. ReLU
# 3. Leaky ReLU
#
# ## Answer:
# [Sigmoid]

# %% [markdown]
# # "Sandwich" layers
# There are some common patterns of layers that are frequently used in neural nets. For example, affine layers are frequently followed by a ReLU nonlinearity. To make these common patterns easy, we define several convenience layers in the file `cs231n/layer_utils.py`.
#
# For now take a look at the `affine_relu_forward` and `affine_relu_backward` functions, and run the following to numerically gradient check the backward pass:

# %%
from cs231n.layer_utils import affine_relu_forward, affine_relu_backward
np.random.seed(231)
x = np.random.randn(2, 3, 4)
w = np.random.randn(12, 10)
b = np.random.randn(10)
dout = np.random.randn(2, 10)

out, cache = affine_relu_forward(x, w, b)
dx, dw, db = affine_relu_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: affine_relu_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_relu_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_relu_forward(x, w, b)[0], b, dout)

# Relative error should be around e-10 or less
print('Testing affine_relu_forward and affine_relu_backward:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_relu_forward and affine_relu_backward:
# dx error:  6.750562121603446e-11
# dw error:  8.162015570444288e-11
# db error:  7.826724021458994e-12

# %% [markdown]
# # Loss layers: Softmax and SVM
# You implemented these loss functions in the last assignment, so we'll give them to you for free here. You should still make sure you understand how they work by looking at the implementations in `cs231n/layers.py`.
#
# You can make sure that the implementations are correct by running the following:

# %%
np.random.seed(231)
num_classes, num_inputs = 10, 50
x = 0.001 * np.random.randn(num_inputs, num_classes)
y = np.random.randint(num_classes, size=num_inputs)

dx_num = eval_numerical_gradient(lambda x: svm_loss(x, y)[0], x, verbose=False)
loss, dx = svm_loss(x, y)

# Test svm_loss function. Loss should be around 9 and dx error should be around the order of e-9
print('Testing svm_loss:')
print('loss: ', loss)
print('dx error: ', rel_error(dx_num, dx))

dx_num = eval_numerical_gradient(lambda x: softmax_loss(x, y)[0], x, verbose=False)
loss, dx = softmax_loss(x, y)

# Test softmax_loss function. Loss should be close to 2.3 and dx error should be around e-8
print('\nTesting softmax_loss:')
print('loss: ', loss)
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing svm_loss:
# loss:  8.999602749096233
# dx error:  1.4021566006651672e-09
#
# Testing softmax_loss:
# loss:  2.302545844500738
# dx error:  9.384673161989355e-09

# %% [markdown]
# # Two-layer network
# In the previous assignment you implemented a two-layer neural network in a single monolithic class. Now that you have implemented modular versions of the necessary layers, you will reimplement the two layer network using these modular implementations.
#
# Open the file `cs231n/classifiers/fc_net.py` and complete the implementation of the `TwoLayerNet` class. This class will serve as a model for the other networks you will implement in this assignment, so read through it to make sure you understand the API. You can run the cell below to test your implementation.

# %%
np.random.seed(231)
N, D, H, C = 3, 5, 50, 7
X = np.random.randn(N, D)
y = np.random.randint(C, size=N)

std = 1e-3
model = TwoLayerNet(input_dim=D, hidden_dim=H, num_classes=C, weight_scale=std)

print('Testing initialization ... ')
W1_std = abs(model.params['W1'].std() - std)
b1 = model.params['b1']
W2_std = abs(model.params['W2'].std() - std)
b2 = model.params['b2']
assert W1_std < std / 10, 'First layer weights do not seem right'
assert np.all(b1 == 0), 'First layer biases do not seem right'
assert W2_std < std / 10, 'Second layer weights do not seem right'
assert np.all(b2 == 0), 'Second layer biases do not seem right'

print('Testing test-time forward pass ... ')
model.params['W1'] = np.linspace(-0.7, 0.3, num=D*H).reshape(D, H)
model.params['b1'] = np.linspace(-0.1, 0.9, num=H)
model.params['W2'] = np.linspace(-0.3, 0.4, num=H*C).reshape(H, C)
model.params['b2'] = np.linspace(-0.9, 0.1, num=C)
X = np.linspace(-5.5, 4.5, num=N*D).reshape(D, N).T
scores = model.loss(X)
correct_scores = np.asarray(
  [[11.53165108,  12.2917344,   13.05181771,  13.81190102,  14.57198434, 15.33206765,  16.09215096],
   [12.05769098,  12.74614105,  13.43459113,  14.1230412,   14.81149128, 15.49994135,  16.18839143],
   [12.58373087,  13.20054771,  13.81736455,  14.43418138,  15.05099822, 15.66781506,  16.2846319 ]])
scores_diff = np.abs(scores - correct_scores).sum()
assert scores_diff < 1e-6, 'Problem with test-time forward pass'

print('Testing training loss (no regularization)')
y = np.asarray([0, 5, 1])
loss, grads = model.loss(X, y)
correct_loss = 3.4702243556
assert abs(loss - correct_loss) < 1e-10, 'Problem with training-time loss'

model.reg = 1.0
loss, grads = model.loss(X, y)
correct_loss = 26.5948426952
assert abs(loss - correct_loss) < 1e-10, 'Problem with regularization loss'

# Errors should be around e-7 or less
for reg in [0.0, 0.7]:
  print('Running numeric gradient check with reg = ', reg)
  model.reg = reg
  loss, grads = model.loss(X, y)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Testing initialization ...
# Testing test-time forward pass ...
# Testing training loss (no regularization)
# Running numeric gradient check with reg =  0.0
# W1 relative error: 1.52e-08
# W2 relative error: 3.48e-10
# b1 relative error: 6.55e-09
# b2 relative error: 4.33e-10
# Running numeric gradient check with reg =  0.7
# W1 relative error: 8.18e-07
# W2 relative error: 2.85e-08
# b1 relative error: 1.09e-09
# b2 relative error: 7.76e-10

# %% [markdown]
# # Solver
# In the previous assignment, the logic for training models was coupled to the models themselves. Following a more modular design, for this assignment we have split the logic for training models into a separate class.
#
# Open the file `cs231n/solver.py` and read through it to familiarize yourself with the API. After doing so, use a `Solver` instance to train a `TwoLayerNet` that achieves at least `50%` accuracy on the validation set.

# %%
model = TwoLayerNet()
best_solver = None
best_acr = -1
best_lr = None
best_hs = None
# best_reg = None
##############################################################################
# TODO: Use a Solver instance to train a TwoLayerNet that achieves at least  #
# 50% accuracy on the validation set.                                        #
##############################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# print ("Train data shape: ",data['X_train'].shape)
# print ("Validation shape: ",data['X_val'].shape)
# model = TwoLayerNet(hidden_dim=100, reg=0)
# print ("W1 shape: ",model.params['W1'].shape)
# print ("W2 shape: ",model.params['W2'].shape)
# print ("b1 shape: ",model.params['b1'].shape)
# print ("b2 shape: ",model.params['b2'].shape)

#What to tune?
'''
    learning rate : 0.0006
    hidden dim: 122
    reg:0 (no tuning for the sake of my time)
    
    train_acr = 0.622000
    val_acr = 0.531000
'''
# learning_rates = [1e-4,1e-3]
# LR_step_size = 10
# LR_list = np.linspace(learning_rates[0],learning_rates[1],LR_step_size)

# hidden_sizes = [100,150]
# hs_step_size = 10
# HS_list = np.linspace(hidden_sizes[0],hidden_sizes[1],hs_step_size).astype('int8') 
# for lr in LR_list:
#     print (f"traingin with lr = {lr}")
#     model = TwoLayerNet(hidden_dim=100, reg=0)

#     solver = Solver(model, data,
#                     update_rule='sgd',
#                     optim_config={
#                       'learning_rate': lr,
#                     },
#                     lr_decay=0.95,
#                     num_epochs=10, batch_size=100,
#                     print_every=100)
#     solver.train()
#     if solver.best_val_acc > best_acr:
#         best_solver = solver
#         best_acr = solver.best_val_acc
#         best_lr = lr
        
# print (f"best learning rate: {best_lr}, best val acc: {best_acr}")
# best learning rate: 0.0006000000000000001, best val acc: 0.524

# hidden_sizes = [100, 150]
# hs_step_size = 10
# HS_list = np.linspace(hidden_sizes[0],hidden_sizes[1],hs_step_size).astype('int32') 
# print(HS_list)

# for hs in HS_list:
#     print (f"training hs: {hs}")
#     model = TwoLayerNet(hidden_dim=hs, reg=0)

#     solver = Solver(model, data,
#                     update_rule='sgd',
#                     optim_config={
#                       'learning_rate': 0.000600000000001,
#                     },
#                     lr_decay=0.95,
#                     num_epochs=10, batch_size=100,
#                     print_every=100)
#     solver.train()
#     del model
#     if solver.best_val_acc > best_acr:
#         best_solver = solver
#         best_acr = solver.best_val_acc
#         best_hs = hs
        
# print (f"best learning rate: {best_hs}, best val acc: {best_acr}")

model = TwoLayerNet(hidden_dim=122, reg=0)

solver = Solver(model, data,
                update_rule='sgd',
                optim_config={
                  'learning_rate': 0.000600000000001,
                },
                lr_decay=0.95,
                num_epochs=10, batch_size=100,
                print_every=100)
solver.train()
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
##############################################################################
#                             END OF YOUR CODE                               #
##############################################################################
# Out:
# initialized
# (Iteration 1 / 4900) loss: 2.302719
# (Epoch 0 / 10) train acc: 0.162000; val_acc: 0.139000
# (Iteration 101 / 4900) loss: 1.889440
# (Iteration 201 / 4900) loss: 1.628808
# (Iteration 301 / 4900) loss: 1.699334
# (Iteration 401 / 4900) loss: 1.661172
# (Epoch 1 / 10) train acc: 0.432000; val_acc: 0.446000
# (Iteration 501 / 4900) loss: 1.557230
# (Iteration 601 / 4900) loss: 1.602883
# (Iteration 701 / 4900) loss: 1.346370
# (Iteration 801 / 4900) loss: 1.523961
# (Iteration 901 / 4900) loss: 1.550514
# (Epoch 2 / 10) train acc: 0.497000; val_acc: 0.470000
# (Iteration 1001 / 4900) loss: 1.440126
# (Iteration 1101 / 4900) loss: 1.664647
# (Iteration 1201 / 4900) loss: 1.296007
# (Iteration 1301 / 4900) loss: 1.431934
# (Iteration 1401 / 4900) loss: 1.388394
# (Epoch 3 / 10) train acc: 0.514000; val_acc: 0.482000
# (Iteration 1501 / 4900) loss: 1.299625
# (Iteration 1601 / 4900) loss: 1.444375
# (Iteration 1701 / 4900) loss: 1.507291
# (Iteration 1801 / 4900) loss: 1.292671
# (Iteration 1901 / 4900) loss: 1.173737
# (Epoch 4 / 10) train acc: 0.551000; val_acc: 0.494000
# (Iteration 2001 / 4900) loss: 1.316578
# (Iteration 2101 / 4900) loss: 1.135204
# (Iteration 2201 / 4900) loss: 1.373931
# (Iteration 2301 / 4900) loss: 1.491212
# (Iteration 2401 / 4900) loss: 1.449239
# (Epoch 5 / 10) train acc: 0.545000; val_acc: 0.494000
# (Iteration 2501 / 4900) loss: 1.270017
# (Iteration 2601 / 4900) loss: 1.447329
# (Iteration 2701 / 4900) loss: 1.479571
# (Iteration 2801 / 4900) loss: 1.230460
# (Iteration 2901 / 4900) loss: 1.161915
# (Epoch 6 / 10) train acc: 0.571000; val_acc: 0.486000
# (Iteration 3001 / 4900) loss: 1.304380
# (Iteration 3101 / 4900) loss: 1.142752
# (Iteration 3201 / 4900) loss: 1.188096
# (Iteration 3301 / 4900) loss: 1.214112
# (Iteration 3401 / 4900) loss: 1.284714
# (Epoch 7 / 10) train acc: 0.591000; val_acc: 0.519000
# (Iteration 3501 / 4900) loss: 1.391301
# (Iteration 3601 / 4900) loss: 1.200472
# (Iteration 3701 / 4900) loss: 1.154752
# (Iteration 3801 / 4900) loss: 1.169217
# (Iteration 3901 / 4900) loss: 1.174807
# (Epoch 8 / 10) train acc: 0.579000; val_acc: 0.507000
# (Iteration 4001 / 4900) loss: 1.175635
# (Iteration 4101 / 4900) loss: 1.197561
# (Iteration 4201 / 4900) loss: 1.439061
# (Iteration 4301 / 4900) loss: 1.117106
# (Iteration 4401 / 4900) loss: 1.133635
# (Epoch 9 / 10) train acc: 0.622000; val_acc: 0.531000
# (Iteration 4501 / 4900) loss: 1.199015
# (Iteration 4601 / 4900) loss: 1.314943
# (Iteration 4701 / 4900) loss: 0.926706
# (Iteration 4801 / 4900) loss: 1.331264
# (Epoch 10 / 10) train acc: 0.607000; val_acc: 0.513000

# %%
# Run this cell to visualize training loss and train / val accuracy

plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %% [markdown]
# # Multilayer network
# Next you will implement a fully-connected network with an arbitrary number of hidden layers.
#
# Read through the `FullyConnectedNet` class in the file `cs231n/classifiers/fc_net.py`.
#
# Implement the initialization, the forward pass, and the backward pass. For the moment don't worry about implementing dropout or batch/layer normalization; we will add those features soon.

# %% [markdown]
# ## Initial loss and gradient check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. Do the initial losses seem reasonable?
#
# For gradient checking, you should expect to see errors around 1e-7 or less.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
    print('Running check with reg = ', reg)
    model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            reg=reg, weight_scale=5e-2, dtype=np.float64)
    

    loss, grads = model.loss(X, y)
    print('Initial loss: ', loss)
  
  # Most of the errors should be on the order of e-7 or smaller.   
  # NOTE: It is fine however to see an error for W2 on the order of e-5
  # for the check when reg = 0.0
for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Running check with reg =  0
# Initializing your model....
# Init your model...successfully
# Computing the loss
# Done computing the loss:  2.3004790897684924
# Initial loss:  2.3004790897684924
# Running check with reg =  3.14
# Initializing your model....
# Init your model...successfully
# Computing the loss
# Done computing the loss:  7.052114776533016
# Initial loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114324951823
# Computing the loss
# Done computing the loss:  7.0521152284282085
# Computing the loss
# Done computing the loss:  7.052112132888702
# Computing the loss
# Done computing the loss:  7.0521174204913315
# Computing the loss
# Done computing the loss:  7.052117093465495
# Computing the loss
# Done computing the loss:  7.052112459914536
# Computing the loss
# Done computing the loss:  7.052115040683715
# Computing the loss
# Done computing the loss:  7.052114512696317
# Computing the loss
# Done computing the loss:  7.0521144929915325
# Computing the loss
# Done computing the loss:  7.0521150603885
# Computing the loss
# Done computing the loss:  7.052113164109141
# Computing the loss
# Done computing the loss:  7.052116389270891
# Computing the loss
# Done computing the loss:  7.052114742597761
# Computing the loss
# Done computing the loss:  7.052114810782273
# Computing the loss
# Done computing the loss:  7.052114234387758
# Computing the loss
# Done computing the loss:  7.052115318992275
# Computing the loss
# Done computing the loss:  7.052113357596647
# Computing the loss
# Done computing the loss:  7.052116195783385
# Computing the loss
# Done computing the loss:  7.052114890355444
# Computing the loss
# Done computing the loss:  7.0521146630245894
# Computing the loss
# Done computing the loss:  7.052112638118285
# Computing the loss
# Done computing the loss:  7.052116915261748
# Computing the loss
# Done computing the loss:  7.052116869225847
# Computing the loss
# Done computing the loss:  7.052112684154187
# Computing the loss
# Done computing the loss:  7.05211439705267
# Computing the loss
# Done computing the loss:  7.052115156327361
# Computing the loss
# Done computing the loss:  7.052111368430383
# Computing the loss
# Done computing the loss:  7.052118184949649
# Computing the loss
# Done computing the loss:  7.052115580881964
# Computing the loss
# Done computing the loss:  7.052113972498068
# Computing the loss
# Done computing the loss:  7.052116683881069
# Computing the loss
# Done computing the loss:  7.052112869498963
# Computing the loss
# Done computing the loss:  7.052117012543053
# Computing the loss
# Done computing the loss:  7.05211254083698
# Computing the loss
# Done computing the loss:  7.052117687982855
# Computing the loss
# Done computing the loss:  7.05211186539718
# Computing the loss
# Done computing the loss:  7.052115223721266
# Computing the loss
# Done computing the loss:  7.0521143296587665
# Computing the loss
# Done computing the loss:  7.052115249043711
# Computing the loss
# Done computing the loss:  7.052114304336322
# Computing the loss
# Done computing the loss:  7.052116174431839
# Computing the loss
# Done computing the loss:  7.052113378948193
# Computing the loss
# Done computing the loss:  7.052114037696591
# Computing the loss
# Done computing the loss:  7.0521155156834405
# Computing the loss
# Done computing the loss:  7.052116527985532
# Computing the loss
# Done computing the loss:  7.052113025394509
# Computing the loss
# Done computing the loss:  7.052113290309442
# Computing the loss
# Done computing the loss:  7.05211626307059
# Computing the loss
# Done computing the loss:  7.052113200877251
# Computing the loss
# Done computing the loss:  7.052116352502781
# Computing the loss
# Done computing the loss:  7.052112616921303
# Computing the loss
# Done computing the loss:  7.052116936458729
# Computing the loss
# Done computing the loss:  7.052116980009832
# Computing the loss
# Done computing the loss:  7.052112573370199
# Computing the loss
# Done computing the loss:  7.052116958036283
# Computing the loss
# Done computing the loss:  7.052112595343756
# Computing the loss
# Done computing the loss:  7.052115587395688
# Computing the loss
# Done computing the loss:  7.052113965984344
# Computing the loss
# Done computing the loss:  7.052109375783893
# Computing the loss
# Done computing the loss:  7.052120177596139
# Computing the loss
# Done computing the loss:  7.052115024712154
# Computing the loss
# Done computing the loss:  7.052114528667878
# Computing the loss
# Done computing the loss:  7.052112726330132
# Computing the loss
# Done computing the loss:  7.0521168270499
# Computing the loss
# Done computing the loss:  7.052113701246004
# Computing the loss
# Done computing the loss:  7.052115852134028
# Computing the loss
# Done computing the loss:  7.052112131423394
# Computing the loss
# Done computing the loss:  7.052117421956638
# Computing the loss
# Done computing the loss:  7.052117500597662
# Computing the loss
# Done computing the loss:  7.05211205278239
# Computing the loss
# Done computing the loss:  7.05211490428786
# Computing the loss
# Done computing the loss:  7.052114649092172
# Computing the loss
# Done computing the loss:  7.05211506091015
# Computing the loss
# Done computing the loss:  7.052114492469881
# Computing the loss
# Done computing the loss:  7.05211890889082
# Computing the loss
# Done computing the loss:  7.052110644489227
# Computing the loss
# Done computing the loss:  7.052117281435274
# Computing the loss
# Done computing the loss:  7.0521122719447575
# Computing the loss
# Done computing the loss:  7.052113102363961
# Computing the loss
# Done computing the loss:  7.05211645101607
# Computing the loss
# Done computing the loss:  7.05211546997316
# Computing the loss
# Done computing the loss:  7.052114083406872
# Computing the loss
# Done computing the loss:  7.052115395561956
# Computing the loss
# Done computing the loss:  7.052114157818079
# Computing the loss
# Done computing the loss:  7.052113712612164
# Computing the loss
# Done computing the loss:  7.052115840767884
# Computing the loss
# Done computing the loss:  7.052110199518079
# Computing the loss
# Done computing the loss:  7.052119353861952
# Computing the loss
# Done computing the loss:  7.052115122208152
# Computing the loss
# Done computing the loss:  7.05211443117188
# Computing the loss
# Done computing the loss:  7.0521147222733935
# Computing the loss
# Done computing the loss:  7.052114831106638
# Computing the loss
# Done computing the loss:  7.052116522743073
# Computing the loss
# Done computing the loss:  7.05211303063696
# Computing the loss
# Done computing the loss:  7.052115012016168
# Computing the loss
# Done computing the loss:  7.052114541363876
# Computing the loss
# Done computing the loss:  7.052113742257445
# Computing the loss
# Done computing the loss:  7.052115811122587
# Computing the loss
# Done computing the loss:  7.052115829720997
# Computing the loss
# Done computing the loss:  7.052113723659039
# Computing the loss
# Done computing the loss:  7.052117791858559
# Computing the loss
# Done computing the loss:  7.052111761521475
# Computing the loss
# Done computing the loss:  7.052115644318199
# Computing the loss
# Done computing the loss:  7.052113909061838
# Computing the loss
# Done computing the loss:  7.052113233023354
# Computing the loss
# Done computing the loss:  7.052116320356678
# Computing the loss
# Done computing the loss:  7.0521125063849635
# Computing the loss
# Done computing the loss:  7.052117046995068
# Computing the loss
# Done computing the loss:  7.052112971082851
# Computing the loss
# Done computing the loss:  7.052116582297212
# Computing the loss
# Done computing the loss:  7.052115479753935
# Computing the loss
# Done computing the loss:  7.0521140736260985
# Computing the loss
# Done computing the loss:  7.052116409759293
# Computing the loss
# Done computing the loss:  7.052113143620742
# Computing the loss
# Done computing the loss:  7.052115129319433
# Computing the loss
# Done computing the loss:  7.052114424060626
# Computing the loss
# Done computing the loss:  7.052118858227811
# Computing the loss
# Done computing the loss:  7.052110695152226
# Computing the loss
# Done computing the loss:  7.052118195040763
# Computing the loss
# Done computing the loss:  7.052111358339271
# Computing the loss
# Done computing the loss:  7.052114283373122
# Computing the loss
# Done computing the loss:  7.05211527000691
# Computing the loss
# Done computing the loss:  7.052116539589182
# Computing the loss
# Done computing the loss:  7.05211301379085
# Computing the loss
# Done computing the loss:  7.052114554294203
# Computing the loss
# Done computing the loss:  7.052114999085831
# Computing the loss
# Done computing the loss:  7.052116647480668
# Computing the loss
# Done computing the loss:  7.052112905899364
# Computing the loss
# Done computing the loss:  7.052114625825457
# Computing the loss
# Done computing the loss:  7.052114927554575
# Computing the loss
# Done computing the loss:  7.052115480918792
# Computing the loss
# Done computing the loss:  7.05211407246124
# Computing the loss
# Done computing the loss:  7.052115982971848
# Computing the loss
# Done computing the loss:  7.052113570408184
# Computing the loss
# Done computing the loss:  7.052112150269439
# Computing the loss
# Done computing the loss:  7.052117403110595
# Computing the loss
# Done computing the loss:  7.052113468985264
# Computing the loss
# Done computing the loss:  7.0521160843947674
# Computing the loss
# Done computing the loss:  7.052112492546995
# Computing the loss
# Done computing the loss:  7.0521170608330355
# Computing the loss
# Done computing the loss:  7.052114553907283
# Computing the loss
# Done computing the loss:  7.0521149994727494
# Computing the loss
# Done computing the loss:  7.052115265731808
# Computing the loss
# Done computing the loss:  7.052114287648225
# Computing the loss
# Done computing the loss:  7.052113736118628
# Computing the loss
# Done computing the loss:  7.052115817261404
# Computing the loss
# Done computing the loss:  7.05211418795739
# Computing the loss
# Done computing the loss:  7.052115365422642
# Computing the loss
# Done computing the loss:  7.052115114156374
# Computing the loss
# Done computing the loss:  7.052114439223662
# Computing the loss
# Done computing the loss:  7.052114201325906
# Computing the loss
# Done computing the loss:  7.052115352054126
# Computing the loss
# Done computing the loss:  7.052117187964544
# Computing the loss
# Done computing the loss:  7.052112365415488
# Computing the loss
# Done computing the loss:  7.052113342075447
# Computing the loss
# Done computing the loss:  7.052116211304589
# Computing the loss
# Done computing the loss:  7.052114053919981
# Computing the loss
# Done computing the loss:  7.052115499460051
# Computing the loss
# Done computing the loss:  7.052111994425747
# Computing the loss
# Done computing the loss:  7.0521175589542855
# Computing the loss
# Done computing the loss:  7.052116915828122
# Computing the loss
# Done computing the loss:  7.05211263755191
# Computing the loss
# Done computing the loss:  7.052115626274396
# Computing the loss
# Done computing the loss:  7.052113927105641
# Computing the loss
# Done computing the loss:  7.052115274831236
# Computing the loss
# Done computing the loss:  7.052114278548796
# Computing the loss
# Done computing the loss:  7.052113741387506
# Computing the loss
# Done computing the loss:  7.052115811992525
# Computing the loss
# Done computing the loss:  7.052112439182762
# Computing the loss
# Done computing the loss:  7.052117114197269
# Computing the loss
# Done computing the loss:  7.052113401793031
# Computing the loss
# Done computing the loss:  7.052116151587001
# Computing the loss
# Done computing the loss:  7.052115446632087
# Computing the loss
# Done computing the loss:  7.052114106747947
# Computing the loss
# Done computing the loss:  7.052115496868144
# Computing the loss
# Done computing the loss:  7.052114056511887
# Computing the loss
# Done computing the loss:  7.052113776824169
# Computing the loss
# Done computing the loss:  7.052115776555863
# Computing the loss
# Done computing the loss:  7.052117805380117
# Computing the loss
# Done computing the loss:  7.052111747999918
# Computing the loss
# Done computing the loss:  7.052114732151826
# Computing the loss
# Done computing the loss:  7.052114821228209
# Computing the loss
# Done computing the loss:  7.052117276553986
# Computing the loss
# Done computing the loss:  7.052112276826052
# Computing the loss
# Done computing the loss:  7.052115922884131
# Computing the loss
# Done computing the loss:  7.052113630495901
# Computing the loss
# Done computing the loss:  7.052115753540073
# Computing the loss
# Done computing the loss:  7.052113799839959
# Computing the loss
# Done computing the loss:  7.052114745451709
# Computing the loss
# Done computing the loss:  7.052114807928323
# Computing the loss
# Done computing the loss:  7.0521140472049355
# Computing the loss
# Done computing the loss:  7.052115506175099
# Computing the loss
# Done computing the loss:  7.052112623484484
# Computing the loss
# Done computing the loss:  7.052116929895552
# Computing the loss
# Done computing the loss:  7.0521170041379015
# Computing the loss
# Done computing the loss:  7.052112549242137
# Computing the loss
# Done computing the loss:  7.0521141546093915
# Computing the loss
# Done computing the loss:  7.0521153987706455
# Computing the loss
# Done computing the loss:  7.052113313623805
# Computing the loss
# Done computing the loss:  7.05211623975623
# Computing the loss
# Done computing the loss:  7.052116125687042
# Computing the loss
# Done computing the loss:  7.05211342769299
# Computing the loss
# Done computing the loss:  7.052117650899353
# Computing the loss
# Done computing the loss:  7.0521119024806795
# Computing the loss
# Done computing the loss:  7.052114842591498
# Computing the loss
# Done computing the loss:  7.052114710788536
# Computing the loss
# Done computing the loss:  7.052113989384768
# Computing the loss
# Done computing the loss:  7.052115563995264
# Computing the loss
# Done computing the loss:  7.052115191374184
# Computing the loss
# Done computing the loss:  7.052114362005848
# Computing the loss
# Done computing the loss:  7.052114208666558
# Computing the loss
# Done computing the loss:  7.0521153447134735
# Computing the loss
# Done computing the loss:  7.052114451345398
# Computing the loss
# Done computing the loss:  7.052115102034634
# Computing the loss
# Done computing the loss:  7.052115475704799
# Computing the loss
# Done computing the loss:  7.052114077675235
# Computing the loss
# Done computing the loss:  7.052116440151266
# Computing the loss
# Done computing the loss:  7.052113113228765
# Computing the loss
# Done computing the loss:  7.052115462106723
# Computing the loss
# Done computing the loss:  7.0521140912733085
# Computing the loss
# Done computing the loss:  7.052113557967715
# Computing the loss
# Done computing the loss:  7.052115995412318
# Computing the loss
# Done computing the loss:  7.052116900827555
# Computing the loss
# Done computing the loss:  7.052112652552477
# Computing the loss
# Done computing the loss:  7.052116327698155
# Computing the loss
# Done computing the loss:  7.052113225681877
# Computing the loss
# Done computing the loss:  7.052114367398435
# Computing the loss
# Done computing the loss:  7.052115185981597
# Computing the loss
# Done computing the loss:  7.052115256588155
# Computing the loss
# Done computing the loss:  7.052114296791883
# Computing the loss
# Done computing the loss:  7.052114953841073
# Computing the loss
# Done computing the loss:  7.0521145995389585
# Computing the loss
# Done computing the loss:  7.0521143572025515
# Computing the loss
# Done computing the loss:  7.05211519617748
# Computing the loss
# Done computing the loss:  7.052114379186463
# Computing the loss
# Done computing the loss:  7.052115174193573
# Computing the loss
# Done computing the loss:  7.0521146582375085
# Computing the loss
# Done computing the loss:  7.052114895142523
# Computing the loss
# Done computing the loss:  7.0521132897395455
# Computing the loss
# Done computing the loss:  7.052116263640486
# Computing the loss
# Done computing the loss:  7.05211458095959
# Computing the loss
# Done computing the loss:  7.0521149724204415
# Computing the loss
# Done computing the loss:  7.052118812677298
# Computing the loss
# Done computing the loss:  7.052110740702734
# Computing the loss
# Done computing the loss:  7.052115576559061
# Computing the loss
# Done computing the loss:  7.052113976820972
# Computing the loss
# Done computing the loss:  7.052113397977996
# Computing the loss
# Done computing the loss:  7.052116155402036
# Computing the loss
# Done computing the loss:  7.052113333236173
# Computing the loss
# Done computing the loss:  7.0521162201438585
# Computing the loss
# Done computing the loss:  7.052115492813023
# Computing the loss
# Done computing the loss:  7.052114060567009
# Computing the loss
# Done computing the loss:  7.0521150465256275
# Computing the loss
# Done computing the loss:  7.052114506854404
# Computing the loss
# Done computing the loss:  7.052111069047239
# Computing the loss
# Done computing the loss:  7.052118484332793
# Computing the loss
# Done computing the loss:  7.052115619287561
# Computing the loss
# Done computing the loss:  7.05211393409247
# Computing the loss
# Done computing the loss:  7.052114823006466
# Computing the loss
# Done computing the loss:  7.052114730373566
# Computing the loss
# Done computing the loss:  7.0521157424609076
# Computing the loss
# Done computing the loss:  7.052113810919125
# Computing the loss
# Done computing the loss:  7.052112069570311
# Computing the loss
# Done computing the loss:  7.052117483809722
# Computing the loss
# Done computing the loss:  7.052114200078478
# Computing the loss
# Done computing the loss:  7.052115353301554
# Computing the loss
# Done computing the loss:  7.05211455532775
# Computing the loss
# Done computing the loss:  7.052114998052282
# Computing the loss
# Done computing the loss:  7.052113011853346
# Computing the loss
# Done computing the loss:  7.052116541526686
# Computing the loss
# Done computing the loss:  7.052116295813765
# Computing the loss
# Done computing the loss:  7.052113257566266
# Computing the loss
# Done computing the loss:  7.0521130304497675
# Computing the loss
# Done computing the loss:  7.052116522930265
# Computing the loss
# Done computing the loss:  7.052112146963394
# Computing the loss
# Done computing the loss:  7.052117406416638
# Computing the loss
# Done computing the loss:  7.0521127222685305
# Computing the loss
# Done computing the loss:  7.052116831111501
# Computing the loss
# Done computing the loss:  7.052111780933515
# Computing the loss
# Done computing the loss:  7.052117772446517
# Computing the loss
# Done computing the loss:  7.052114448614601
# Computing the loss
# Done computing the loss:  7.052115104765432
# Computing the loss
# Done computing the loss:  7.052114114685966
# Computing the loss
# Done computing the loss:  7.052115438694066
# Computing the loss
# Done computing the loss:  7.052115697506331
# Computing the loss
# Done computing the loss:  7.052113855873719
# Computing the loss
# Done computing the loss:  7.0521133515209895
# Computing the loss
# Done computing the loss:  7.052116201859042
# Computing the loss
# Done computing the loss:  7.052112088639887
# Computing the loss
# Done computing the loss:  7.052117464740145
# Computing the loss
# Done computing the loss:  7.052114564080619
# Computing the loss
# Done computing the loss:  7.052114989299413
# Computing the loss
# Done computing the loss:  7.052112880538637
# Computing the loss
# Done computing the loss:  7.052116672841395
# Computing the loss
# Done computing the loss:  7.052114640571115
# Computing the loss
# Done computing the loss:  7.05211491280893
# Computing the loss
# Done computing the loss:  7.052111961810788
# Computing the loss
# Done computing the loss:  7.0521175915692424
# Computing the loss
# Done computing the loss:  7.052114984434331
# Computing the loss
# Done computing the loss:  7.052114568945701
# Computing the loss
# Done computing the loss:  7.052115255655109
# Computing the loss
# Done computing the loss:  7.0521142977249225
# Computing the loss
# Done computing the loss:  7.052115608801366
# Computing the loss
# Done computing the loss:  7.052113944578666
# Computing the loss
# Done computing the loss:  7.0521139798282135
# Computing the loss
# Done computing the loss:  7.052115573551818
# Computing the loss
# Done computing the loss:  7.052116237075932
# Computing the loss
# Done computing the loss:  7.0521133163041
# Computing the loss
# Done computing the loss:  7.052112294893024
# Computing the loss
# Done computing the loss:  7.052117258487042
# Computing the loss
# Done computing the loss:  7.052113921533526
# Computing the loss
# Done computing the loss:  7.052115631846506
# Computing the loss
# Done computing the loss:  7.052114305590294
# Computing the loss
# Done computing the loss:  7.052115247789738
# Computing the loss
# Done computing the loss:  7.052117193307666
# Computing the loss
# Done computing the loss:  7.05211236007239
# Computing the loss
# Done computing the loss:  7.052113517616014
# Computing the loss
# Done computing the loss:  7.052116035764018
# Computing the loss
# Done computing the loss:  7.052113250282897
# Computing the loss
# Done computing the loss:  7.052116303097135
# Computing the loss
# Done computing the loss:  7.052114327058741
# Computing the loss
# Done computing the loss:  7.05211522632129
# Computing the loss
# Done computing the loss:  7.0521129914747736
# Computing the loss
# Done computing the loss:  7.052116561905262
# Computing the loss
# Done computing the loss:  7.05211351566494
# Computing the loss
# Done computing the loss:  7.0521160377151
# Computing the loss
# Done computing the loss:  7.052115675731917
# Computing the loss
# Done computing the loss:  7.0521138776481145
# Computing the loss
# Done computing the loss:  7.052113401457555
# Computing the loss
# Done computing the loss:  7.052116151922477
# Computing the loss
# Done computing the loss:  7.052112683347625
# Computing the loss
# Done computing the loss:  7.052116870032407
# Computing the loss
# Done computing the loss:  7.052113177674885
# Computing the loss
# Done computing the loss:  7.052116375705148
# Computing the loss
# Done computing the loss:  7.052114217036568
# Computing the loss
# Done computing the loss:  7.052115336343471
# Computing the loss
# Done computing the loss:  7.052114069512424
# Computing the loss
# Done computing the loss:  7.052115483867608
# Computing the loss
# Done computing the loss:  7.052115381865061
# Computing the loss
# Done computing the loss:  7.052114171514974
# Computing the loss
# Done computing the loss:  7.052116543521765
# Computing the loss
# Done computing the loss:  7.052113009858269
# Computing the loss
# Done computing the loss:  7.05211636236802
# Computing the loss
# Done computing the loss:  7.052113191012018
# Computing the loss
# Done computing the loss:  7.052114646610972
# Computing the loss
# Done computing the loss:  7.052114906769059
# Computing the loss
# Done computing the loss:  7.052116764589494
# Computing the loss
# Done computing the loss:  7.052112788790537
# Computing the loss
# Done computing the loss:  7.052114625681239
# Computing the loss
# Done computing the loss:  7.052114927698813
# Computing the loss
# Done computing the loss:  7.052116120300575
# Computing the loss
# Done computing the loss:  7.052113433079459
# Computing the loss
# Done computing the loss:  7.05211480965766
# Computing the loss
# Done computing the loss:  7.052114743722377
# Computing the loss
# Done computing the loss:  7.052117131833414
# Computing the loss
# Done computing the loss:  7.052112421546637
# Computing the loss
# Done computing the loss:  7.052114157709419
# Computing the loss
# Done computing the loss:  7.052115395670617
# Computing the loss
# Done computing the loss:  7.0521159569415035
# Computing the loss
# Done computing the loss:  7.052113596438531
# Computing the loss
# Done computing the loss:  7.052114733922245
# Computing the loss
# Done computing the loss:  7.0521148194577865
# Computing the loss
# Done computing the loss:  7.052117321894756
# Computing the loss
# Done computing the loss:  7.0521122314852756
# Computing the loss
# Done computing the loss:  7.052116418782521
# Computing the loss
# Done computing the loss:  7.052113134597511
# Computing the loss
# Done computing the loss:  7.052116108979763
# Computing the loss
# Done computing the loss:  7.052113444400269
# Computing the loss
# Done computing the loss:  7.052114716404755
# Computing the loss
# Done computing the loss:  7.052114836975277
# Computing the loss
# Done computing the loss:  7.052113636018922
# Computing the loss
# Done computing the loss:  7.052115917361109
# Computing the loss
# Done computing the loss:  7.052115258633965
# Computing the loss
# Done computing the loss:  7.052114294746068
# Computing the loss
# Done computing the loss:  7.052116032336599
# Computing the loss
# Done computing the loss:  7.052113521043434
# Computing the loss
# Done computing the loss:  7.052112211309831
# Computing the loss
# Done computing the loss:  7.052117342070201
# Computing the loss
# Done computing the loss:  7.052116899258163
# Computing the loss
# Done computing the loss:  7.052112654121869
# Computing the loss
# Done computing the loss:  7.052115386875581
# Computing the loss
# Done computing the loss:  7.052114166504451
# Computing the loss
# Done computing the loss:  7.052114567705447
# Computing the loss
# Done computing the loss:  7.052114985674585
# Computing the loss
# Done computing the loss:  7.052115374354832
# Computing the loss
# Done computing the loss:  7.0521141790251995
# Computing the loss
# Done computing the loss:  7.05211496836527
# Computing the loss
# Done computing the loss:  7.0521145850147615
# Computing the loss
# Done computing the loss:  7.05211188594371
# Computing the loss
# Done computing the loss:  7.052117667436322
# Computing the loss
# Done computing the loss:  7.052116705697782
# Computing the loss
# Done computing the loss:  7.05211284768225
# Computing the loss
# Done computing the loss:  7.052116358501306
# Computing the loss
# Done computing the loss:  7.052113194878727
# Computing the loss
# Done computing the loss:  7.0521140609813875
# Computing the loss
# Done computing the loss:  7.052115492398646
# Computing the loss
# Done computing the loss:  7.052114994722128
# Computing the loss
# Done computing the loss:  7.0521145586579035
# Computing the loss
# Done computing the loss:  7.052114404474116
# Computing the loss
# Done computing the loss:  7.052115148905917
# Computing the loss
# Done computing the loss:  7.052116730662661
# Computing the loss
# Done computing the loss:  7.05211282271737
# Computing the loss
# Done computing the loss:  7.052114133372298
# Computing the loss
# Done computing the loss:  7.052115420007736
# Computing the loss
# Done computing the loss:  7.052115084188694
# Computing the loss
# Done computing the loss:  7.052114469191339
# Computing the loss
# Done computing the loss:  7.052115153571739
# Computing the loss
# Done computing the loss:  7.052114399808293
# Computing the loss
# Done computing the loss:  7.05211559314474
# Computing the loss
# Done computing the loss:  7.052113960235292
# Computing the loss
# Done computing the loss:  7.052115855155957
# Computing the loss
# Done computing the loss:  7.052113698224074
# Computing the loss
# Done computing the loss:  7.052114267927827
# Computing the loss
# Done computing the loss:  7.052115285452206
# Computing the loss
# Done computing the loss:  7.052117094954081
# Computing the loss
# Done computing the loss:  7.052112458425952
# Computing the loss
# Done computing the loss:  7.052114270127893
# Computing the loss
# Done computing the loss:  7.052115283252139
# Computing the loss
# Done computing the loss:  7.052115510529131
# Computing the loss
# Done computing the loss:  7.052114042850904
# Computing the loss
# Done computing the loss:  7.052115864949677
# Computing the loss
# Done computing the loss:  7.0521136884303575
# Computing the loss
# Done computing the loss:  7.052111754807028
# Computing the loss
# Done computing the loss:  7.052117798573009
# Computing the loss
# Done computing the loss:  7.052114461009662
# Computing the loss
# Done computing the loss:  7.052115092370369
# Computing the loss
# Done computing the loss:  7.052116650589028
# Computing the loss
# Done computing the loss:  7.052112902791004
# Computing the loss
# Done computing the loss:  7.052115327885841
# Computing the loss
# Done computing the loss:  7.052114225494192
# Computing the loss
# Done computing the loss:  7.052114424470237
# Computing the loss
# Done computing the loss:  7.052115128909796
# Computing the loss
# Done computing the loss:  7.052112065965731
# Computing the loss
# Done computing the loss:  7.052117487414305
# Computing the loss
# Done computing the loss:  7.052114585033685
# Computing the loss
# Done computing the loss:  7.052114968346352
# Computing the loss
# Done computing the loss:  7.052115945431262
# Computing the loss
# Done computing the loss:  7.052113607948774
# Computing the loss
# Done computing the loss:  7.052116675019513
# Computing the loss
# Done computing the loss:  7.0521128783605205
# Computing the loss
# Done computing the loss:  7.052114988325
# Computing the loss
# Done computing the loss:  7.052114565055032
# Computing the loss
# Done computing the loss:  7.052115085321448
# Computing the loss
# Done computing the loss:  7.052114468058583
# Computing the loss
# Done computing the loss:  7.052113462282555
# Computing the loss
# Done computing the loss:  7.052116091097477
# Computing the loss
# Done computing the loss:  7.052114705364071
# Computing the loss
# Done computing the loss:  7.052114848015961
# Computing the loss
# Done computing the loss:  7.05211417215025
# Computing the loss
# Done computing the loss:  7.052115381229782
# Computing the loss
# Done computing the loss:  7.052110228982715
# Computing the loss
# Done computing the loss:  7.052119324397316
# Computing the loss
# Done computing the loss:  7.052113626895753
# Computing the loss
# Done computing the loss:  7.052115926484278
# Computing the loss
# Done computing the loss:  7.052113351129439
# Computing the loss
# Done computing the loss:  7.052116202250593
# Computing the loss
# Done computing the loss:  7.052115461416214
# Computing the loss
# Done computing the loss:  7.052114091963817
# Computing the loss
# Done computing the loss:  7.052114361719705
# Computing the loss
# Done computing the loss:  7.052115191660326
# Computing the loss
# Done computing the loss:  7.052118610896425
# Computing the loss
# Done computing the loss:  7.052110942483606
# Computing the loss
# Done computing the loss:  7.052113588493067
# Computing the loss
# Done computing the loss:  7.052115964886965
# Computing the loss
# Done computing the loss:  7.052114058163697
# Computing the loss
# Done computing the loss:  7.052115495216334
# Computing the loss
# Done computing the loss:  7.0521151202811545
# Computing the loss
# Done computing the loss:  7.052114433098877
# Computing the loss
# Done computing the loss:  7.052118595469222
# Computing the loss
# Done computing the loss:  7.052110957910811
# Computing the loss
# Done computing the loss:  7.052114975786624
# Computing the loss
# Done computing the loss:  7.052114577593407
# Computing the loss
# Done computing the loss:  7.052113982281563
# Computing the loss
# Done computing the loss:  7.05211557109847
# Computing the loss
# Done computing the loss:  7.052115958766679
# Computing the loss
# Done computing the loss:  7.0521135946133535
# Computing the loss
# Done computing the loss:  7.052116244846831
# Computing the loss
# Done computing the loss:  7.052113308533201
# Computing the loss
# Done computing the loss:  7.0521134304800785
# Computing the loss
# Done computing the loss:  7.052116122899954
# Computing the loss
# Done computing the loss:  7.0521176487039945
# Computing the loss
# Done computing the loss:  7.052111904676037
# Computing the loss
# Done computing the loss:  7.052115396622034
# Computing the loss
# Done computing the loss:  7.052114156758
# Computing the loss
# Done computing the loss:  7.052116965763483
# Computing the loss
# Done computing the loss:  7.05211258761655
# Computing the loss
# Done computing the loss:  7.0521153605143985
# Computing the loss
# Done computing the loss:  7.052114192865633
# Computing the loss
# Done computing the loss:  7.052113530788881
# Computing the loss
# Done computing the loss:  7.052116022591152
# Computing the loss
# Done computing the loss:  7.052114462898416
# Computing the loss
# Done computing the loss:  7.052115090481616
# Computing the loss
# Done computing the loss:  7.052115892658161
# Computing the loss
# Done computing the loss:  7.052113660721872
# Computing the loss
# Done computing the loss:  7.052115881366117
# Computing the loss
# Done computing the loss:  7.052113672013919
# Computing the loss
# Done computing the loss:  7.0521142714389695
# Computing the loss
# Done computing the loss:  7.052115281941062
# Computing the loss
# Done computing the loss:  7.052116286065802
# Computing the loss
# Done computing the loss:  7.052113267314232
# Computing the loss
# Done computing the loss:  7.052116592702366
# Computing the loss
# Done computing the loss:  7.052112960677667
# Computing the loss
# Done computing the loss:  7.052113428671507
# Computing the loss
# Done computing the loss:  7.052116124708528
# Computing the loss
# Done computing the loss:  7.052115234384731
# Computing the loss
# Done computing the loss:  7.052114318995302
# Computing the loss
# Done computing the loss:  7.052116392328021
# Computing the loss
# Done computing the loss:  7.052113161052011
# Computing the loss
# Done computing the loss:  7.052114841114846
# Computing the loss
# Done computing the loss:  7.052114712265193
# Computing the loss
# Done computing the loss:  7.052110896300548
# Computing the loss
# Done computing the loss:  7.052118657079484
# Computing the loss
# Done computing the loss:  7.052114834193489
# Computing the loss
# Done computing the loss:  7.0521147191865445
# Computing the loss
# Done computing the loss:  7.05211678739071
# Computing the loss
# Done computing the loss:  7.05211276598933
# Computing the loss
# Done computing the loss:  7.052114698231537
# Computing the loss
# Done computing the loss:  7.052114855148497
# Computing the loss
# Done computing the loss:  7.052114226375258
# Computing the loss
# Done computing the loss:  7.052115327004776
# Computing the loss
# Done computing the loss:  7.052112685762768
# Computing the loss
# Done computing the loss:  7.052116867617263
# Computing the loss
# Done computing the loss:  7.052115890275166
# Computing the loss
# Done computing the loss:  7.0521136631048655
# Computing the loss
# Done computing the loss:  7.052112966392737
# Computing the loss
# Done computing the loss:  7.0521165869872995
# Computing the loss
# Done computing the loss:  7.0521162696919095
# Computing the loss
# Done computing the loss:  7.052113283688122
# Computing the loss
# Done computing the loss:  7.052114267274384
# Computing the loss
# Done computing the loss:  7.052115286105647
# Computing the loss
# Done computing the loss:  7.052113994433642
# Computing the loss
# Done computing the loss:  7.052115558946389
# Computing the loss
# Done computing the loss:  7.052115158654445
# Computing the loss
# Done computing the loss:  7.052114394725586
# Computing the loss
# Done computing the loss:  7.052117786228
# Computing the loss
# Done computing the loss:  7.052111767152034
# Computing the loss
# Done computing the loss:  7.052113810002925
# Computing the loss
# Done computing the loss:  7.052115743377107
# Computing the loss
# Done computing the loss:  7.05211527272624
# Computing the loss
# Done computing the loss:  7.052114280653791
# Computing the loss
# Done computing the loss:  7.052116294356075
# Computing the loss
# Done computing the loss:  7.052113259023956
# Computing the loss
# Done computing the loss:  7.0521164797288
# Computing the loss
# Done computing the loss:  7.052113073651233
# Computing the loss
# Done computing the loss:  7.0521151116319905
# Computing the loss
# Done computing the loss:  7.05211444174804
# Computing the loss
# Done computing the loss:  7.052113234562182
# Computing the loss
# Done computing the loss:  7.052116318817849
# Computing the loss
# Done computing the loss:  7.05211606429779
# Computing the loss
# Done computing the loss:  7.0521134890822506
# Computing the loss
# Done computing the loss:  7.0521147603987
# Computing the loss
# Done computing the loss:  7.052114792981332
# Computing the loss
# Done computing the loss:  7.052114091969462
# Computing the loss
# Done computing the loss:  7.052115461410571
# Computing the loss
# Done computing the loss:  7.05211605146236
# Computing the loss
# Done computing the loss:  7.052113501917678
# Computing the loss
# Done computing the loss:  7.052112925991175
# Computing the loss
# Done computing the loss:  7.052116627388859
# Computing the loss
# Done computing the loss:  7.0521144550948325
# Computing the loss
# Done computing the loss:  7.052115098285199
# Computing the loss
# Done computing the loss:  7.052116140897498
# Computing the loss
# Done computing the loss:  7.052113412482535
# Computing the loss
# Done computing the loss:  7.052115041349605
# Computing the loss
# Done computing the loss:  7.052114512030427
# Computing the loss
# Done computing the loss:  7.05211617205484
# Computing the loss
# Done computing the loss:  7.0521133813252
# Computing the loss
# Done computing the loss:  7.052111430406615
# Computing the loss
# Done computing the loss:  7.0521181229734164
# Computing the loss
# Done computing the loss:  7.052111788557736
# Computing the loss
# Done computing the loss:  7.052117764822296
# Computing the loss
# Done computing the loss:  7.052114689345582
# Computing the loss
# Done computing the loss:  7.05211486403445
# Computing the loss
# Done computing the loss:  7.052115251859579
# Computing the loss
# Done computing the loss:  7.052114301520453
# Computing the loss
# Done computing the loss:  7.052115574110324
# Computing the loss
# Done computing the loss:  7.0521139792697145
# Computing the loss
# Done computing the loss:  7.05211537843861
# Computing the loss
# Done computing the loss:  7.052114174941422
# Computing the loss
# Done computing the loss:  7.052113965294538
# Computing the loss
# Done computing the loss:  7.052115588085494
# Computing the loss
# Done computing the loss:  7.052115681157779
# Computing the loss
# Done computing the loss:  7.052113872222254
# Computing the loss
# Done computing the loss:  7.052115351007369
# Computing the loss
# Done computing the loss:  7.052114202372665
# Computing the loss
# Done computing the loss:  7.052114232993934
# Computing the loss
# Done computing the loss:  7.052115320386098
# Computing the loss
# Done computing the loss:  7.052117632171935
# Computing the loss
# Done computing the loss:  7.0521119212080965
# Computing the loss
# Done computing the loss:  7.052115363229567
# Computing the loss
# Done computing the loss:  7.052114190150482
# Computing the loss
# Done computing the loss:  7.052113680246897
# Computing the loss
# Done computing the loss:  7.052115873133134
# Computing the loss
# Done computing the loss:  7.052114593047188
# Computing the loss
# Done computing the loss:  7.052114960332844
# Computing the loss
# Done computing the loss:  7.052116682424379
# Computing the loss
# Done computing the loss:  7.052112870955666
# Computing the loss
# Done computing the loss:  7.052115221273634
# Computing the loss
# Done computing the loss:  7.052114332106399
# Computing the loss
# Done computing the loss:  7.052114902557831
# Computing the loss
# Done computing the loss:  7.052114650822202
# W1 relative error: 6.86e-09
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052115261478749
# Computing the loss
# Done computing the loss:  7.052114291901283
# Computing the loss
# Done computing the loss:  7.052116632914146
# Computing the loss
# Done computing the loss:  7.052112920465886
# Computing the loss
# Done computing the loss:  7.052114718098191
# Computing the loss
# Done computing the loss:  7.052114835281841
# Computing the loss
# Done computing the loss:  7.052112806578295
# Computing the loss
# Done computing the loss:  7.052116746801737
# Computing the loss
# Done computing the loss:  7.052114840444653
# Computing the loss
# Done computing the loss:  7.052114712935379
# Computing the loss
# Done computing the loss:  7.05211195600613
# Computing the loss
# Done computing the loss:  7.052117597373901
# Computing the loss
# Done computing the loss:  7.052114772968142
# Computing the loss
# Done computing the loss:  7.052114780411889
# Computing the loss
# Done computing the loss:  7.052113336344256
# Computing the loss
# Done computing the loss:  7.052116217035776
# Computing the loss
# Done computing the loss:  7.0521149326792045
# Computing the loss
# Done computing the loss:  7.052114620700828
# Computing the loss
# Done computing the loss:  7.052115813247826
# Computing the loss
# Done computing the loss:  7.052113740132206
# Computing the loss
# Done computing the loss:  7.052115442955759
# Computing the loss
# Done computing the loss:  7.052114110424273
# Computing the loss
# Done computing the loss:  7.052116446874932
# Computing the loss
# Done computing the loss:  7.052113106505099
# Computing the loss
# Done computing the loss:  7.052114474389541
# Computing the loss
# Done computing the loss:  7.05211507899049
# Computing the loss
# Done computing the loss:  7.05211459717311
# Computing the loss
# Done computing the loss:  7.052114956206922
# Computing the loss
# Done computing the loss:  7.0521147726627245
# Computing the loss
# Done computing the loss:  7.052114780717307
# Computing the loss
# Done computing the loss:  7.052115709634759
# Computing the loss
# Done computing the loss:  7.052113843745273
# Computing the loss
# Done computing the loss:  7.052116106460427
# Computing the loss
# Done computing the loss:  7.052113446919605
# Computing the loss
# Done computing the loss:  7.052112258330574
# Computing the loss
# Done computing the loss:  7.052117295049458
# Computing the loss
# Done computing the loss:  7.05211327615328
# Computing the loss
# Done computing the loss:  7.052116277226752
# Computing the loss
# Done computing the loss:  7.052113795861283
# Computing the loss
# Done computing the loss:  7.052115757518749
# Computing the loss
# Done computing the loss:  7.05211168871107
# Computing the loss
# Done computing the loss:  7.052117864668961
# Computing the loss
# Done computing the loss:  7.052115081538398
# Computing the loss
# Done computing the loss:  7.052114471841634
# Computing the loss
# Done computing the loss:  7.0521141413345205
# Computing the loss
# Done computing the loss:  7.052115412045511
# Computing the loss
# Done computing the loss:  7.052113506964034
# Computing the loss
# Done computing the loss:  7.052116046415998
# Computing the loss
# Done computing the loss:  7.052114664061323
# Computing the loss
# Done computing the loss:  7.052114889318709
# Computing the loss
# Done computing the loss:  7.052117702919844
# Computing the loss
# Done computing the loss:  7.052111850460188
# Computing the loss
# Done computing the loss:  7.052115795790148
# Computing the loss
# Done computing the loss:  7.052113757589884
# Computing the loss
# Done computing the loss:  7.052114039964908
# Computing the loss
# Done computing the loss:  7.052115513415123
# Computing the loss
# Done computing the loss:  7.0521144932613495
# Computing the loss
# Done computing the loss:  7.052115060118682
# Computing the loss
# Done computing the loss:  7.0521149686925355
# Computing the loss
# Done computing the loss:  7.052114584687496
# Computing the loss
# Done computing the loss:  7.052112518324765
# Computing the loss
# Done computing the loss:  7.052117035055267
# Computing the loss
# Done computing the loss:  7.052114214782931
# Computing the loss
# Done computing the loss:  7.0521153385971
# Computing the loss
# Done computing the loss:  7.052114691495126
# Computing the loss
# Done computing the loss:  7.052114861884906
# Computing the loss
# Done computing the loss:  7.052116416570646
# Computing the loss
# Done computing the loss:  7.0521131368093855
# Computing the loss
# Done computing the loss:  7.052116108179733
# Computing the loss
# Done computing the loss:  7.052113445200299
# Computing the loss
# Done computing the loss:  7.052113713660424
# Computing the loss
# Done computing the loss:  7.052115839719608
# Computing the loss
# Done computing the loss:  7.052114662735682
# Computing the loss
# Done computing the loss:  7.05211489064435
# Computing the loss
# Done computing the loss:  7.052115018242909
# Computing the loss
# Done computing the loss:  7.0521145351371235
# Computing the loss
# Done computing the loss:  7.052113809911536
# Computing the loss
# Done computing the loss:  7.052115743468495
# Computing the loss
# Done computing the loss:  7.052115122641299
# Computing the loss
# Done computing the loss:  7.052114430738733
# Computing the loss
# Done computing the loss:  7.052113498678054
# Computing the loss
# Done computing the loss:  7.052116054701978
# Computing the loss
# Done computing the loss:  7.052114638313085
# Computing the loss
# Done computing the loss:  7.052114915066946
# Computing the loss
# Done computing the loss:  7.052113324130035
# Computing the loss
# Done computing the loss:  7.052116229249997
# Computing the loss
# Done computing the loss:  7.052112191028754
# Computing the loss
# Done computing the loss:  7.052117362351279
# Computing the loss
# Done computing the loss:  7.052116892891589
# Computing the loss
# Done computing the loss:  7.052112660488443
# Computing the loss
# Done computing the loss:  7.0521178664747985
# Computing the loss
# Done computing the loss:  7.052111686905233
# Computing the loss
# Done computing the loss:  7.052114209207116
# Computing the loss
# Done computing the loss:  7.052115344172916
# Computing the loss
# Done computing the loss:  7.0521146623883215
# Computing the loss
# Done computing the loss:  7.05211489099171
# Computing the loss
# Done computing the loss:  7.052113815126515
# Computing the loss
# Done computing the loss:  7.052115738253517
# Computing the loss
# Done computing the loss:  7.052113805545117
# Computing the loss
# Done computing the loss:  7.052115747834915
# Computing the loss
# Done computing the loss:  7.052115129811924
# Computing the loss
# Done computing the loss:  7.052114423568108
# Computing the loss
# Done computing the loss:  7.052119057228083
# Computing the loss
# Done computing the loss:  7.05211049615195
# Computing the loss
# Done computing the loss:  7.052115767713362
# Computing the loss
# Done computing the loss:  7.05211378566667
# Computing the loss
# Done computing the loss:  7.052113840586381
# Computing the loss
# Done computing the loss:  7.0521157127936505
# Computing the loss
# Done computing the loss:  7.052112906026217
# Computing the loss
# Done computing the loss:  7.052116647353815
# Computing the loss
# Done computing the loss:  7.052114810089184
# Computing the loss
# Done computing the loss:  7.052114743290848
# Computing the loss
# Done computing the loss:  7.052113545765421
# Computing the loss
# Done computing the loss:  7.052116007614612
# Computing the loss
# Done computing the loss:  7.0521150573867635
# Computing the loss
# Done computing the loss:  7.052114495993268
# Computing the loss
# Done computing the loss:  7.0521175274650005
# Computing the loss
# Done computing the loss:  7.052112025915031
# Computing the loss
# Done computing the loss:  7.052112396334456
# Computing the loss
# Done computing the loss:  7.052117157045576
# Computing the loss
# Done computing the loss:  7.052113919902104
# Computing the loss
# Done computing the loss:  7.052115633477928
# Computing the loss
# Done computing the loss:  7.0521139477886035
# Computing the loss
# Done computing the loss:  7.052115605591429
# Computing the loss
# Done computing the loss:  7.052117124205914
# Computing the loss
# Done computing the loss:  7.052112429174125
# Computing the loss
# Done computing the loss:  7.052114600988835
# Computing the loss
# Done computing the loss:  7.0521149523912
# Computing the loss
# Done computing the loss:  7.052114635911024
# Computing the loss
# Done computing the loss:  7.052114917469008
# Computing the loss
# Done computing the loss:  7.052116370101129
# Computing the loss
# Done computing the loss:  7.052113183278909
# Computing the loss
# Done computing the loss:  7.052115964285162
# Computing the loss
# Done computing the loss:  7.052113589094882
# Computing the loss
# Done computing the loss:  7.052116250742327
# Computing the loss
# Done computing the loss:  7.0521133026377125
# Computing the loss
# Done computing the loss:  7.052114174976785
# Computing the loss
# Done computing the loss:  7.052115378403247
# Computing the loss
# Done computing the loss:  7.052113872579167
# Computing the loss
# Done computing the loss:  7.052115680800872
# Computing the loss
# Done computing the loss:  7.052112523775496
# Computing the loss
# Done computing the loss:  7.052117029604536
# Computing the loss
# Done computing the loss:  7.052115973507856
# Computing the loss
# Done computing the loss:  7.052113579872179
# Computing the loss
# Done computing the loss:  7.05211529816664
# Computing the loss
# Done computing the loss:  7.052114255213399
# Computing the loss
# Done computing the loss:  7.052114960924733
# Computing the loss
# Done computing the loss:  7.052114592455306
# Computing the loss
# Done computing the loss:  7.05211760605655
# Computing the loss
# Done computing the loss:  7.052111947323489
# Computing the loss
# Done computing the loss:  7.052116317163965
# Computing the loss
# Done computing the loss:  7.052113236216067
# Computing the loss
# Done computing the loss:  7.052115052399461
# Computing the loss
# ...
# Computing the loss
# Done computing the loss:  7.052115847415175
# Computing the loss
# Done computing the loss:  7.052114740168579
# Computing the loss
# Done computing the loss:  7.052114813211452
# Computing the loss
# Done computing the loss:  7.052114116816346
# Computing the loss
# Done computing the loss:  7.052115436563685
# Computing the loss
# Done computing the loss:  7.052113752068504
# Computing the loss
# Done computing the loss:  7.052115801311528
# Computing the loss
# Done computing the loss:  7.052115796639574
# Computing the loss
# Done computing the loss:  7.052113756740457
# Computing the loss
# Done computing the loss:  7.05211359747765
# Computing the loss
# Done computing the loss:  7.052115955902397
# Computing the loss
# Done computing the loss:  7.052115921402706
# Computing the loss
# Done computing the loss:  7.052113631977338
# Computing the loss
# Done computing the loss:  7.052115387217864
# Computing the loss
# Done computing the loss:  7.052114166162182
# Computing the loss
# Done computing the loss:  7.0521154918953695
# Computing the loss
# Done computing the loss:  7.052114061484676
# Computing the loss
# Done computing the loss:  7.052116714469491
# Computing the loss
# Done computing the loss:  7.052112838910554
# Computing the loss
# Done computing the loss:  7.0521151613162845
# Computing the loss
# Done computing the loss:  7.052114392063761
# Computing the loss
# Done computing the loss:  7.052117341878261
# Computing the loss
# Done computing the loss:  7.052112211501784
# Computing the loss
# Done computing the loss:  7.052113795602137
# Computing the loss
# Done computing the loss:  7.052115757777908
# Computing the loss
# Done computing the loss:  7.052116094098262
# Computing the loss
# Done computing the loss:  7.052113459281783
# Computing the loss
# Done computing the loss:  7.052117105067206
# Computing the loss
# Done computing the loss:  7.0521124483128395
# Computing the loss
# Done computing the loss:  7.052113681043115
# Computing the loss
# Done computing the loss:  7.052115872336917
# Computing the loss
# Done computing the loss:  7.052114325075434
# Computing the loss
# Done computing the loss:  7.052115228304598
# Computing the loss
# Done computing the loss:  7.052114732229279
# Computing the loss
# Done computing the loss:  7.052114821150752
# Computing the loss
# Done computing the loss:  7.052115364198607
# Computing the loss
# Done computing the loss:  7.052114189181425
# Computing the loss
# Done computing the loss:  7.052114877135937
# Computing the loss
# Done computing the loss:  7.052114676244095
# Computing the loss
# Done computing the loss:  7.052113838591354
# Computing the loss
# Done computing the loss:  7.052115714788678
# Computing the loss
# Done computing the loss:  7.052112910046071
# Computing the loss
# Done computing the loss:  7.052116643333961
# Computing the loss
# Done computing the loss:  7.052115905534368
# Computing the loss
# Done computing the loss:  7.052113647845664
# Computing the loss
# Done computing the loss:  7.052115610602469
# Computing the loss
# Done computing the loss:  7.052113942777563
# Computing the loss
# Done computing the loss:  7.0521124923499245
# Computing the loss
# Done computing the loss:  7.052117061030107
# Computing the loss
# Done computing the loss:  7.052109688635007
# Computing the loss
# Done computing the loss:  7.052119864745027
# Computing the loss
# Done computing the loss:  7.052115867132259
# Computing the loss
# Done computing the loss:  7.0521136862477745
# Computing the loss
# Done computing the loss:  7.052112926694791
# Computing the loss
# Done computing the loss:  7.052116626685243
# Computing the loss
# Done computing the loss:  7.052117301628821
# Computing the loss
# Done computing the loss:  7.052112251751213
# Computing the loss
# Done computing the loss:  7.05211408287569
# Computing the loss
# Done computing the loss:  7.052115470504344
# Computing the loss
# Done computing the loss:  7.052113877088814
# Computing the loss
# Done computing the loss:  7.052115676291219
# Computing the loss
# Done computing the loss:  7.052113065712724
# Computing the loss
# Done computing the loss:  7.052116487667309
# Computing the loss
# Done computing the loss:  7.052115021735061
# Computing the loss
# Done computing the loss:  7.052114531644972
# Computing the loss
# Done computing the loss:  7.052114612247427
# Computing the loss
# Done computing the loss:  7.052114941132607
# Computing the loss
# Done computing the loss:  7.052114138158171
# Computing the loss
# Done computing the loss:  7.052115415221863
# Computing the loss
# Done computing the loss:  7.052113752782311
# Computing the loss
# Done computing the loss:  7.052115800597721
# Computing the loss
# Done computing the loss:  7.052118596847706
# Computing the loss
# Done computing the loss:  7.052110956532326
# Computing the loss
# Done computing the loss:  7.052115214772404
# Computing the loss
# Done computing the loss:  7.052114338607629
# Computing the loss
# Done computing the loss:  7.052115124482763
# Computing the loss
# Done computing the loss:  7.052114428897268
# Computing the loss
# Done computing the loss:  7.052115402419201
# Computing the loss
# Done computing the loss:  7.052114150960831
# Computing the loss
# Done computing the loss:  7.052113370355331
# Computing the loss
# Done computing the loss:  7.052116183024701
# Computing the loss
# Done computing the loss:  7.052111991018669
# Computing the loss
# Done computing the loss:  7.052117562361364
# Computing the loss
# Done computing the loss:  7.052116458075481
# Computing the loss
# Done computing the loss:  7.05211309530455
# Computing the loss
# Done computing the loss:  7.052114978700725
# Computing the loss
# Done computing the loss:  7.052114574679306
# Computing the loss
# Done computing the loss:  7.052112655835856
# Computing the loss
# Done computing the loss:  7.052116897544176
# Computing the loss
# Done computing the loss:  7.052114186760222
# Computing the loss
# Done computing the loss:  7.052115366619825
# Computing the loss
# Done computing the loss:  7.0521137098522155
# Computing the loss
# Done computing the loss:  7.052115843527831
# Computing the loss
# Done computing the loss:  7.05211329416966
# Computing the loss
# Done computing the loss:  7.052116259210386
# Computing the loss
# Done computing the loss:  7.052114732432948
# Computing the loss
# Done computing the loss:  7.052114820947098
# Computing the loss
# Done computing the loss:  7.052113770062331
# Computing the loss
# Done computing the loss:  7.052115783317716
# Computing the loss
# Done computing the loss:  7.052116920494383
# Computing the loss
# Done computing the loss:  7.052112632885664
# Computing the loss
# Done computing the loss:  7.05211498536521
# Computing the loss
# Done computing the loss:  7.0521145680148365
# Computing the loss
# Done computing the loss:  7.052113882774428
# Computing the loss
# Done computing the loss:  7.052115670605619
# Computing the loss
# Done computing the loss:  7.052114333052117
# Computing the loss
# Done computing the loss:  7.052115220327929
# Computing the loss
# Done computing the loss:  7.052116462095137
# Computing the loss
# Done computing the loss:  7.052113091284909
# Computing the loss
# Done computing the loss:  7.0521133890494765
# Computing the loss
# Done computing the loss:  7.052116164330555
# Computing the loss
# Done computing the loss:  7.052114033653838
# Computing the loss
# Done computing the loss:  7.052115519726194
# Computing the loss
# Done computing the loss:  7.052115691610565
# Computing the loss
# Done computing the loss:  7.052113861769467
# Computing the loss
# Done computing the loss:  7.052112472602015
# Computing the loss
# Done computing the loss:  7.052117080778017
# Computing the loss
# Done computing the loss:  7.052115870047812
# Computing the loss
# Done computing the loss:  7.0521136833322196
# Computing the loss
# Done computing the loss:  7.052114633004698
# Computing the loss
# Done computing the loss:  7.052114920375334
# Computing the loss
# Done computing the loss:  7.052115493539754
# Computing the loss
# Done computing the loss:  7.052114059840279
# Computing the loss
# Done computing the loss:  7.052114803183368
# Computing the loss
# Done computing the loss:  7.0521147501966635
# Computing the loss
# Done computing the loss:  7.052115927566419
# Computing the loss
# Done computing the loss:  7.052113625813613
# Computing the loss
# Done computing the loss:  7.05211299771628
# Computing the loss
# Done computing the loss:  7.052116555663751
# W3 relative error: 1.32e-08
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114754446135
# Computing the loss
# Done computing the loss:  7.0521147986199
# Computing the loss
# Done computing the loss:  7.052114693520221
# Computing the loss
# Done computing the loss:  7.052114859545816
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.05211481026651
# Computing the loss
# Done computing the loss:  7.052114742799523
# Computing the loss
# Done computing the loss:  7.052114803512792
# Computing the loss
# Done computing the loss:  7.052114749553244
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114719319549
# Computing the loss
# Done computing the loss:  7.052114833746487
# Computing the loss
# Done computing the loss:  7.052114710404253
# Computing the loss
# Done computing the loss:  7.052114842661782
# Computing the loss
# Done computing the loss:  7.052114897156521
# Computing the loss
# Done computing the loss:  7.052114655909518
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114715463338
# Computing the loss
# Done computing the loss:  7.052114837602704
# Computing the loss
# Done computing the loss:  7.052114765054886
# Computing the loss
# Done computing the loss:  7.052114788011149
# Computing the loss
# Done computing the loss:  7.05211484643694
# Computing the loss
# Done computing the loss:  7.052114706629096
# Computing the loss
# Done computing the loss:  7.052114784976205
# Computing the loss
# Done computing the loss:  7.052114768089841
# Computing the loss
# Done computing the loss:  7.052114684142472
# Computing the loss
# Done computing the loss:  7.052114868923566
# Computing the loss
# Done computing the loss:  7.052114832800176
# Computing the loss
# Done computing the loss:  7.052114720265859
# b1 relative error: 1.48e-08
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114855920622
# Computing the loss
# Done computing the loss:  7.0521146971456625
# Computing the loss
# Done computing the loss:  7.052114604426663
# Computing the loss
# Done computing the loss:  7.052114948639448
# Computing the loss
# Done computing the loss:  7.052114487145
# Computing the loss
# Done computing the loss:  7.052115065921107
# Computing the loss
# Done computing the loss:  7.052114892021935
# Computing the loss
# Done computing the loss:  7.052114661044229
# Computing the loss
# Done computing the loss:  7.052114591622626
# Computing the loss
# Done computing the loss:  7.052114961443598
# Computing the loss
# Done computing the loss:  7.052114364194191
# Computing the loss
# Done computing the loss:  7.052115188872125
# Computing the loss
# Done computing the loss:  7.052114592974066
# Computing the loss
# Done computing the loss:  7.052114960092128
# Computing the loss
# Done computing the loss:  7.052114964807359
# Computing the loss
# Done computing the loss:  7.052114588258819
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114864568518
# Computing the loss
# Done computing the loss:  7.05211468849763
# Computing the loss
# Done computing the loss:  7.052114533093618
# Computing the loss
# Done computing the loss:  7.052115019972574
# Computing the loss
# Done computing the loss:  7.052114443512869
# Computing the loss
# Done computing the loss:  7.0521151095533
# Computing the loss
# Done computing the loss:  7.052114327663698
# Computing the loss
# Done computing the loss:  7.0521152254024875
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.05211442289913
# Computing the loss
# Done computing the loss:  7.052115130167195
# Computing the loss
# Done computing the loss:  7.05211513147605
# Computing the loss
# Done computing the loss:  7.052114421590372
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.0521146726020945
# Computing the loss
# Done computing the loss:  7.052114880464149
# Computing the loss
# Done computing the loss:  7.052114221474643
# Computing the loss
# Done computing the loss:  7.052115331591562
# Computing the loss
# Done computing the loss:  7.052114947991793
# Computing the loss
# Done computing the loss:  7.05211460507435
# Computing the loss
# Done computing the loss:  7.052114857733954
# Computing the loss
# Done computing the loss:  7.052114695332159
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052115354728768
# Computing the loss
# Done computing the loss:  7.052114198337396
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.0521153019021074
# Computing the loss
# Done computing the loss:  7.052114251164285
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114921974494
# Computing the loss
# Done computing the loss:  7.052114631091666
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052114776533016
# b2 relative error: 1.72e-09
# Computing the loss
# Done computing the loss:  7.052114776533016
# Computing the loss
# Done computing the loss:  7.052110774173914
# Computing the loss
# Done computing the loss:  7.052118778901099
# Computing the loss
# Done computing the loss:  7.0521157731288255
# Computing the loss
# Done computing the loss:  7.052113779946179
# Computing the loss
# Done computing the loss:  7.0521157770723395
# Computing the loss
# Done computing the loss:  7.052113776002698
# Computing the loss
# Done computing the loss:  7.052115764800365
# Computing the loss
# Done computing the loss:  7.052113788274573
# Computing the loss
# Done computing the loss:  7.0521157784873925
# Computing the loss
# Done computing the loss:  7.052113774587656
# Computing the loss
# Done computing the loss:  7.052115774166361
# Computing the loss
# Done computing the loss:  7.0521137789086525
# Computing the loss
# Done computing the loss:  7.052115783235786
# Computing the loss
# Done computing the loss:  7.0521137698393
# Computing the loss
# Done computing the loss:  7.052110781093531
# Computing the loss
# Done computing the loss:  7.0521187719815375
# Computing the loss
# Done computing the loss:  7.052115775066699
# Computing the loss
# Done computing the loss:  7.052113778008321
# Computing the loss
# Done computing the loss:  7.052115784149948
# Computing the loss
# Done computing the loss:  7.052113768925144
# b3 relative error: 1.80e-10

# %% [markdown]
# As another sanity check, make sure you can overfit a small dataset of 50 images. First we will try a three-layer network with 100 units in each hidden layer. In the following cell, tweak the **learning rate** and **weight initialization scale** to overfit and achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

weight_scale = 1e-2   # Experiment with this!
learning_rate = 1e-4  # Experiment with this!
model = FullyConnectedNet([100, 100],
              weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()

# %% [markdown]
# Now try to use a five-layer network with 100 units on each layer to overfit 50 training examples. Again, you will have to adjust the learning rate and weight initialization scale, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

learning_rate = 2e-3  # Experiment with this!
weight_scale = 1e-5   # Experiment with this!
model = FullyConnectedNet([100, 100, 100, 100],
                weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()

# %% [markdown]
# ## Inline Question 2:
# Did you notice anything about the comparative difficulty of training the three-layer net vs training the five layer net? In particular, based on your experience, which network seemed more sensitive to the initialization scale? Why do you think that is the case?
#
# ## Answer:
# [FILL THIS IN]

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# # SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochastic gradient descent. See the Momentum Update section at http://cs231n.github.io/neural-networks-3/#sgd for more information.
#
# Open the file `cs231n/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than e-8.

# %%
from cs231n.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-3, 'velocity': v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

# Should see relative errors around e-8 or less
print('next_w error: ', rel_error(next_w, expected_next_w))
print('velocity error: ', rel_error(expected_velocity, config['velocity']))

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
  print('running with ', update_rule)
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule,
                  optim_config={
                    'learning_rate': 5e-3,
                  },
                  verbose=True)
  solvers[update_rule] = solver
  solver.train()
  print()

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in solvers.items():
  plt.subplot(3, 1, 1)
  plt.plot(solver.loss_history, 'o', label="loss_%s" % update_rule)
  
  plt.subplot(3, 1, 2)
  plt.plot(solver.train_acc_history, '-o', label="train_acc_%s" % update_rule)

  plt.subplot(3, 1, 3)
  plt.plot(solver.val_acc_history, '-o', label="val_acc_%s" % update_rule)
  
for i in [1, 2, 3]:
  plt.subplot(3, 1, i)
  plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# # RMSProp and Adam
# RMSProp [1] and Adam [2] are update rules that set per-parameter learning rates by using a running average of the second moments of gradients.
#
# In the file `cs231n/optim.py`, implement the RMSProp update rule in the `rmsprop` function and implement the Adam update rule in the `adam` function, and check your implementations using the tests below.
#
# **NOTE:** Please implement the _complete_ Adam update rule (with the bias correction mechanism), not the first simplified version mentioned in the course notes.
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test RMSProp implementation
from cs231n.optim import rmsprop

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
cache = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]])
expected_cache = np.asarray([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('cache error: ', rel_error(expected_cache, config['cache']))

# %%
# Test Adam implementation
from cs231n.optim import adam

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
m = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)
v = np.linspace(0.7, 0.5, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]])
expected_v = np.asarray([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]])
expected_m = np.asarray([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('v error: ', rel_error(expected_v, config['v']))
print('m error: ', rel_error(expected_m, config['m']))

# %% [markdown]
# Once you have debugged your RMSProp and Adam implementations, run the following to train a pair of deep networks using these new update rules:

# %%
learning_rates = {'rmsprop': 1e-4, 'adam': 1e-3}
for update_rule in ['adam', 'rmsprop']:
  print('running with ', update_rule)
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule,
                  optim_config={
                    'learning_rate': learning_rates[update_rule]
                  },
                  verbose=True)
  solvers[update_rule] = solver
  solver.train()
  print()

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in list(solvers.items()):
  plt.subplot(3, 1, 1)
  plt.plot(solver.loss_history, 'o', label=update_rule)
  
  plt.subplot(3, 1, 2)
  plt.plot(solver.train_acc_history, '-o', label=update_rule)

  plt.subplot(3, 1, 3)
  plt.plot(solver.val_acc_history, '-o', label=update_rule)
  
for i in [1, 2, 3]:
  plt.subplot(3, 1, i)
  plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# ## Inline Question 3:
#
# AdaGrad, like Adam, is a per-parameter optimization method that uses the following update rule:
#
# ```
# cache += dw**2
# w += - learning_rate * dw / (np.sqrt(cache) + eps)
# ```
#
# John notices that when he was training a network with AdaGrad that the updates became very small, and that his network was learning slowly. Using your knowledge of the AdaGrad update rule, why do you think the updates would become very small? Would Adam have the same issue?
#
#
# ## Answer:
# [FILL THIS IN]

# %% [markdown]
# # Train a good model!
# Train the best fully-connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least 50% accuracy on the validation set using a fully-connected net.
#
# If you are careful it should be possible to get accuracies above 55%, but we don't require it for this part and won't assign extra credit for doing so. Later in the assignment we will ask you to train the best convolutional network that you can on CIFAR-10, and we would prefer that you spend your effort working on convolutional nets rather than fully-connected nets.
#
# You might find it useful to complete the `BatchNormalization.ipynb` and `Dropout.ipynb` notebooks before completing this part, since those techniques can help you train powerful models.

# %%
best_model = None
################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# find batch/layer normalization and dropout useful. Store your best model in  #
# the best_model variable.                                                     #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

pass

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# %% [markdown]
# # Test your model!
# Run your best model on the validation and test sets. You should achieve above 50% accuracy on the validation set.

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
